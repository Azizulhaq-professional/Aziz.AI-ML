# %% [markdown]
# ## Pandas Fillna()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\DELL XPS\\Desktop\\AI & ML\\Data\\Fortune_5.csv')
df
# Out:
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind   NaN  Financial Services        NaN  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0           NaN
# 3   4         Mattouch   NaN                 NaN     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars         NaN     7%
# 3  7,429,377 Dollars   6597557.0    NaN
# 4                NaN         NaN     8%

# %%
df.fillna(2)
# Out:
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind     2  Financial Services        2.0  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0             2
# 3   4         Mattouch     2                   2     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars         2.0     7%
# 3  7,429,377 Dollars   6597557.0      2
# 4                  2         2.0     8%

# %%
df.fillna({'Name': 'none', 'Profit': 0, 'Growth': 0})
# Out:
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind   NaN  Financial Services        NaN  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0           NaN
# 3   4         Mattouch   NaN                 NaN     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars         0.0     7%
# 3  7,429,377 Dollars   6597557.0      0
# 4                NaN         0.0     8%

# %%
df.fillna(method = "ffill")
# Out:
# C:\Users\DELL XPS\AppData\Local\Temp\ipykernel_16780\1983593268.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill")
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services       2009  $11,757,018
# 1   2        Stripfind   Yes  Financial Services       2010  $12,329,371
# 2   3  Canecorporation    No              Health       2012  $10,597,009
# 3   4         Mattouch   Yes         IT Services       2013  $14,026,934
# 4   5        Techdrill   Yes              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.fillna(method = "bfill")
# Out:
# C:\Users\DELL XPS\AppData\Local\Temp\ipykernel_16780\3988041702.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill")
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind    No  Financial Services     2012.0  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0  $14,026,934
# 3   4         Mattouch   Yes              Health     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   6597557.0     7%
# 3  7,429,377 Dollars   6597557.0     8%
# 4                NaN         NaN     8%

# %%
df.fillna(method = "pad")
# Out:
# C:\Users\DELL XPS\AppData\Local\Temp\ipykernel_16780\2627241924.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "pad")
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services       2009  $11,757,018
# 1   2        Stripfind   Yes  Financial Services       2010  $12,329,371
# 2   3  Canecorporation    No              Health       2012  $10,597,009
# 3   4         Mattouch   Yes         IT Services       2013  $14,026,934
# 4   5        Techdrill   Yes              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.fillna(method = "backfill")
# Out:
# C:\Users\DELL XPS\AppData\Local\Temp\ipykernel_16780\1276121204.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "backfill")
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind    No  Financial Services     2012.0  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0  $14,026,934
# 3   4         Mattouch   Yes              Health     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   6597557.0     7%
# 3  7,429,377 Dollars   6597557.0     8%
# 4                NaN         NaN     8%

# %%
df.fillna(method = "ffill", axis = 1)
# Out:
# C:\Users\DELL XPS\AppData\Local\Temp\ipykernel_16780\2054155988.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill", axis = 1)
#   ID             Name Dates            Industry Inception       Revenue  \
# 0  1          Lamtone   Yes         IT Services      2009  $11,757,018
# 1  2        Stripfind   Yes  Financial Services      2010  $12,329,371
# 2  3  Canecorporation    No              Health      2012  $10,597,009
# 3  4         Mattouch   Yes         IT Services      2013  $14,026,934
# 4  5        Techdrill   Yes              Health      2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.fillna(0, limit = 1)
# Out:
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind     0  Financial Services        0.0  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0             0
# 3   4         Mattouch   NaN                   0     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars         0.0     7%
# 3  7,429,377 Dollars   6597557.0      0
# 4                  0         NaN     8%

# %%
df.fillna(method = "ffill", limit= 1)
# Out:
# C:\Users\DELL XPS\AppData\Local\Temp\ipykernel_16780\2226593190.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill", limit= 1)
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services       2009  $11,757,018
# 1   2        Stripfind   Yes  Financial Services       2010  $12,329,371
# 2   3  Canecorporation    No              Health       2012  $10,597,009
# 3   4         Mattouch   Yes         IT Services       2013  $14,026,934
# 4   5        Techdrill   Yes              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.fillna(5, inplace = True)
df
# Out:
#    ID             Name Dates            Industry  Inception       Revenue  \
# 0   1          Lamtone   Yes         IT Services     2009.0  $11,757,018
# 1   2        Stripfind     5  Financial Services        5.0  $12,329,371
# 2   3  Canecorporation    No              Health     2012.0             5
# 3   4         Mattouch     5                   5     2013.0  $14,026,934
# 4   5        Techdrill   Yes              Health     2009.0  $10,573,990
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars         5.0     7%
# 3  7,429,377 Dollars   6597557.0      5
# 4                  5         5.0     8%
